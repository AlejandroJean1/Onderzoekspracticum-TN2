# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# Om ons experiment te starten hebben we de opstelling zo gezet dat we nog voldoende ruimte hebben om het gewicht van de grond te houden.
# Vooraf aan elk experiment wordt de eigenfrequentie bepaald aan de hand van een tik met de vinger op de draad

# %%
# 0.5 mm diameter?
T345 = np.array([28, 30, 41, 48, 57, 70, 77, 90, 115]) # Celsius
u_T345 = 2
eigen_f345 = np.array([350.4, 349.9, 349.2, 348.2, 347.2, 346.4, 344.5, 342.7 ,337.7]) # Hz
u_f345 = 1

# 0.1 mm diameter voor 22.5, 49.8 

T225 = np.array([27, 45, 60, 81, 91, 100, 129, 159, 174, 205, 236]) # Celsius
u_T225 = 2
eigen_f225 = np.array([854.49, 842.28, 830.07, 817.87, 805.66, 799.56, 775.14, 769.04, 750.73, 720.21, 677.49]) # Hz
u_f225 = 1 # Vanaf 100 graden ...ehhh

T498 = np.array([27, 45, 64, 81, 115, 135, 155, 202, 263, 350, 450]) # Celsius
u_T498 = 3 # Onzekerheid 3 graden
eigen_f498 = np.array([280.76, 268.55, 256.34, 244.14, 225.83, 207.51, 195.31, 177, 152.58, 109.86, 30.51]) # Hz
u_f498 = 1 # Vanaf 100 graden ...ehhh

plt.figure(figsize=[12, 8])
plt.plot(T345, eigen_f345, "k.", label="Lengte: 24.5 cm")
# plt.errorbar(T345, eigen_f345, yerr=u_f345, fmt="none", ecolor="k")
plt.xlabel("T (C)")
plt.ylabel("f (Hz)")
plt.legend()
plt.show()


plt.figure(figsize=[12, 8])
plt.plot(T225, eigen_f225, "r.", label="Lengte: 22.5 cm")
plt.xlabel("T (C)")
plt.ylabel("f (Hz)")
plt.legend()
plt.show()

plt.figure(figsize=[12, 8])
plt.plot(T498, eigen_f498, "b.", label="Lengte: 49.8 cm")
plt.xlabel("T (C)")
plt.ylabel("f (Hz)")
plt.legend()
plt.show()

# %% [markdown]
# We hebben ook geprobeerd om met een lengte van 17 cm de frequentie te meten maar hierbij was het erg moeilijk om de eigenfrequentie te zien, hierdoor is deze meting niet afgemaakt en niet meegenomen in het rapport.
#
# - Elke meting boven de 95 C heeft geen accurate temperatuur wegens de limitaties van onze thermokoppel
